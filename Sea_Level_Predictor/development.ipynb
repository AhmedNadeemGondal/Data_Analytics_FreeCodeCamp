# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
df = pd.read_csv('epa-sea-level.csv')
df.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
# Create the scatter plot
plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'])

# Set the plot title and axis labels
# plt.title('Rise in Sea Level')
# plt.xlabel('Year')
# plt.ylabel('Sea Level (inches)')

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])

# Create a range of years up to 2050
years = range(df['Year'].min(), 2051)

# Calculate the corresponding sea level values using the regression equation
sea_level = slope * years + intercept

# Plot the regression line
plt.plot(years, sea_level, color='red')

# Filter the data from 2000 onwards
df_filtered = df[df['Year'] >= 2000]

# Create the scatter plot for the filtered data
plt.scatter(df_filtered['Year'], df_filtered['CSIRO Adjusted Sea Level'], label='Actual Data')

# Set the plot title and axis labels
plt.title('Rise in Sea Level')
plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')

# Perform linear regression on the filtered data
slope, intercept, r_value, p_value, std_err = linregress(df_filtered['Year'], df_filtered['CSIRO Adjusted Sea Level'])

# Create a range of years from 2000 to the maximum year in the filtered data
years_extended = range(2000, 2051)

# Calculate the corresponding sea level values using the regression equation
sea_level_extended = slope * years_extended + intercept

# Plot the regression line for the filtered data
plt.plot(df_filtered['Year'], slope * df_filtered['Year'] + intercept, color='red', label='Regression Line')

# Plot the extended regression line
plt.plot(years_extended, sea_level_extended, color='blue', label='Extended Regression Line')

# Show the legend
plt.legend()
return_value = plt.gca()
# Show the plot
plt.show()

# %%
return_value.get_xticks().tolist()
return_value.get_children()[0].get_offsets().data.tolist()
expected = [7.06107985777146, 7.227507131103323, 7.393934404435242, 7.560361677767105, 7.726788951098968, 7.89321622443083, 8.059643497762693, 8.226070771094555, 8.392498044426418, 8.55892531775828, 8.725352591090143, 8.891779864422006, 9.058207137753925, 9.224634411085788, 9.39106168441765, 9.557488957749513, 9.723916231081375, 9.890343504413238, 10.0567707777451, 10.223198051076963, 10.389625324408826, 10.556052597740688, 10.72247987107255, 10.88890714440447, 11.055334417736333, 11.221761691068195, 11.388188964400058, 11.55461623773192, 11.721043511063783, 11.887470784395646, 12.053898057727508, 12.220325331059371, 12.386752604391233, 12.553179877723153, 12.719607151055015, 12.886034424386878, 13.05246169771874, 13.218888971050603, 13.385316244382466, 13.551743517714328, 13.718170791046191, 13.884598064378054, 14.051025337709916, 14.217452611041836, 14.383879884373698, 14.55030715770556, 14.716734431037423, 14.883161704369286, 15.049588977701148, 15.216016251033011, 15.382443524364874]
len(return_value.get_lines()[1].get_ydata().tolist()),len(expected)
return_value.get_lines()[1].get_ydata().tolist()
# return_value.get_lines()[0].get_ydata().tolist()
# return_value.get_lines()[1].get_ydata().tolist()
sea_level_extended
# Out:
# array([ 7.06107986,  7.22750713,  7.3939344 ,  7.56036168,  7.72678895,
#         7.89321622,  8.0596435 ,  8.22607077,  8.39249804,  8.55892532,
#         8.72535259,  8.89177986,  9.05820714,  9.22463441,  9.39106168,
#         9.55748896,  9.72391623,  9.8903435 , 10.05677078, 10.22319805,
#        10.38962532, 10.5560526 , 10.72247987, 10.88890714, 11.05533442,
#        11.22176169, 11.38818896, 11.55461624, 11.72104351, 11.88747078,
#        12.05389806, 12.22032533, 12.3867526 , 12.55317988, 12.71960715,
#        12.88603442, 13.0524617 , 13.21888897, 13.38531624, 13.55174352,
#        13.71817079, 13.88459806, 14.05102534, 14.21745261, 14.38387988,
#        14.55030716, 14.71673443, 14.8831617 , 15.04958898, 15.21601625,
#        15.38244352])
